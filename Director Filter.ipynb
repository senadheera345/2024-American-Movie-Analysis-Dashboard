# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv(file_path, encoding='latin1')
df
# Out:
#     Opening              Title  \
# 0     APRIL             Música
# 1         5     The First Omen
# 2       NaN         Monkey Man
# 3       NaN  The Greatest Hits
# 4       NaN          Parachute
# ..      ...                ...
# 369     NaN    The Fire Inside
# 370     NaN         Better Man
# 371     NaN           Babygirl
# 372     NaN         Los Frikis
# 373      27   Bloody Axe Wound
#
#                                     Production company  \
# 0       Amazon MGM Studios/Wonderland Sound and Vision
# 1               20th Century Studios/TSG Entertainment
# 2    Universal Pictures/Bron Studios/Thunder Road F...
# 3                            Searchlight Pictures/Hulu
# 4                               Vertical Entertainment
# ..                                                 ...
# 369                                Metro-Goldwyn-Mayer
# 370                                 Paramount Pictures
# 371                                            A24/2AM
# ...

# %% [markdown]
# ## Bind ##

# %%
import pandas as pd
import os

# Path to the folder containing the CSV files
folder_path = "C:/Users/Administrator/Desktop/PowerBiDax/Web Scraping/movie data"

# List to store data from each file
data_frames = []

# Loop through all files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_csv(file_path)  # Read the CSV into a DataFrame
        data_frames.append(df)  # Append the DataFrame to the list

# Combine all DataFrames
combined_df = pd.concat(data_frames, ignore_index=True)

# Save the combined DataFrame to a new CSV file
output_file = "combined_data.csv"
combined_df.to_csv(output_file, index=False)

print(f"All CSV files combined and saved as '{output_file}'")
# Out:
# All CSV files combined and saved as 'combined_data.csv'

# %%
df
# Out:
#     Opening              Title  \
# 0     APRIL             Música
# 1         5     The First Omen
# 2       NaN         Monkey Man
# 3       NaN  The Greatest Hits
# 4       NaN          Parachute
# ..      ...                ...
# 369     NaN    The Fire Inside
# 370     NaN         Better Man
# 371     NaN           Babygirl
# 372     NaN         Los Frikis
# 373      27   Bloody Axe Wound
#
#                                     Production company  \
# 0       Amazon MGM Studios/Wonderland Sound and Vision
# 1               20th Century Studios/TSG Entertainment
# 2    Universal Pictures/Bron Studios/Thunder Road F...
# 3                            Searchlight Pictures/Hulu
# 4                               Vertical Entertainment
# ..                                                 ...
# 369                                Metro-Goldwyn-Mayer
# 370                                 Paramount Pictures
# 371                                            A24/2AM
# ...

# %%
import re
# Improved function to extract director names
def extract_director(cast_and_crew):
    match = re.search(r"([\w\s.'-]+)\s*\(director", cast_and_crew, re.IGNORECASE)
    return match.group(1) if match else None

# Apply the function to create a new column
df["Director"] = df["Cast and crew"].apply(extract_director)

# %%
output_file_path = r"C:/Users/Administrator/Desktop/PowerBiDax/Web Scraping/movie data/preprocessed data/UpdatedDataset2.csv"

# Write the DataFrame to a CSV file
df.to_csv(output_file_path, index=False)

# %% [markdown]
# ## IMDB Rating ##

# %%
import requests
import pandas as pd

# Your OMDb API key
API_KEY = '6f4c1d44'

# List of movie titles
movies = [
"The Line", 
    "Exhibiting Forgiveness", "High Tide", "To Fall in Love", "Canary Black", 
    "Venom: The Last Dance","Conclave", "Your Monster", "Don't Move", "Magpie", "La cocina", 
    "Darla in Space", "All You Need Is Blood", "1 Million Followers", "Hangdog", 
    "Let's Start a Cult", "Amityville: Where the Echo Lives", "Time Cut", "Here", 
    "Juror #2", "Blitz", "A Real Pain", "Absolution", "The Gutter", "The Graduates", 
    "The Eye of the Salamander", "Lost on a Mountain in Maine", "Meet Me Next Christmas", 
    "A Sudden Case of Christmas", "Heretic", "The Best Christmas Pageant Ever", 
    "The Piano Lesson", "Elevation", "Christmas Eve in Miller's Point", "Bird", 
    "Love Bomb", "It's Coming", "Hot Frosty", "Red One", "Daruma", "Breakup Season", 
    "Swap", "The Merry Gentlemen", "Wicked", "Gladiator II", "Spellbound", "Armor", 
    "Out of My Mind", "Bonhoeffer", "The Fix", "Dear Santa", "Watchmen Chapter II", 
    "Hemet, or the Landlady Don't Drink Tea", "A Great Divide", "Moana 2", "Queer", 
    "Maria", "Our Little Secret", "Sweethearts", "Nutcrackers", "Y2K", "Nightbitch", 
    "The Six Triple Eight", "The Order", "Werewolves", "The Return", "Oh, Canada", 
    "Mary", "Jenni", "Kraven the Hunter", "The Lord of the Rings: The War of the Rohirrim", 
    "Carry-On", "Paramount Pictures/Republic Pictures/Constantin Film", "Nickel Boys", 
    "The Last Showgirl", "Dirty Angels", "Filthy Animals", "The Activated Man", 
    "The Little Mermaid", "Glue Trap", "Mufasa: The Lion King", "Sonic the Hedgehog 3", 
    "The Brutalist", "Homestead", "Nosferatu", "A Complete Unknown", "The Fire Inside", 
    "Better Man", "Babygirl", "Los Frikis", "Bloody Axe Wound"

]

# Function to get IMDb rating using OMDb API
def get_imdb_rating(movie):
    url = f"http://www.omdbapi.com/?t={movie}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if data.get('Response') == 'True':
        return data.get('imdbRating')
    else:
        return None

# List to store movie names and their IMDb ratings
movie_ratings = []

# Loop through the movie list and get IMDb ratings
for movie in movies:
    rating = get_imdb_rating(movie)
    movie_ratings.append({'Title': movie, 'IMDb Rating': rating})

# Create a DataFrame to organize the data
df = pd.DataFrame(movie_ratings)

# Save the data to an Excel file
df.to_excel('movie_imdb_ratings3.xlsx', index=False)

print("Ratings extracted and saved to 'movie_imdb_ratings.xlsx'")
# Out:
# Ratings extracted and saved to 'movie_imdb_ratings.xlsx'

# %% [markdown]
# ## Released Date ##

# %%
import requests
import pandas as pd

# Your OMDb API key
API_KEY = '6f4c1d44'

# List of movie titles
movies = [
    "Conclave", "Your Monster", "Don't Move", "Magpie", "La cocina", 
    "Darla in Space", "All You Need Is Blood", "1 Million Followers", "Hangdog", 
    "Let's Start a Cult", "Amityville: Where the Echo Lives", "Time Cut", "Here", 
    "Juror #2", "Blitz", "A Real Pain", "Absolution", "The Gutter", "The Graduates", 
    "The Eye of the Salamander", "Lost on a Mountain in Maine", "Meet Me Next Christmas", 
    "A Sudden Case of Christmas", "Heretic", "The Best Christmas Pageant Ever", 
    "The Piano Lesson", "Elevation", "Christmas Eve in Miller's Point", "Bird", 
    "Love Bomb", "It's Coming", "Hot Frosty", "Red One", "Daruma", "Breakup Season", 
    "Swap", "The Merry Gentlemen", "Wicked", "Gladiator II", "Spellbound", "Armor", 
    "Out of My Mind", "Bonhoeffer", "The Fix", "Dear Santa", "Watchmen Chapter II", 
    "Hemet, or the Landlady Don't Drink Tea", "A Great Divide", "Moana 2", "Queer", 
    "Maria", "Our Little Secret", "Sweethearts", "Nutcrackers", "Y2K", "Nightbitch", 
    "The Six Triple Eight", "The Order", "Werewolves", "The Return", "Oh, Canada", 
    "Mary", "Jenni", "Kraven the Hunter", "The Lord of the Rings: The War of the Rohirrim", 
    "Carry-On", "Paramount Pictures/Republic Pictures/Constantin Film", "Nickel Boys", 
    "The Last Showgirl", "Dirty Angels", "Filthy Animals", "The Activated Man", 
    "The Little Mermaid", "Glue Trap", "Mufasa: The Lion King", "Sonic the Hedgehog 3", 
    "The Brutalist", "Homestead", "Nosferatu", "A Complete Unknown", "The Fire Inside", 
    "Better Man", "Babygirl", "Los Frikis", "Bloody Axe Wound"

]

# Function to get the release date using OMDb API
def get_release_date(movie):
    url = f"http://www.omdbapi.com/?t={movie}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if data.get('Response') == 'True':
        return data.get('Released')
    else:
        return None

# List to store movie names and their release dates
movie_release_dates = []

# Loop through the movie list and get release dates
for movie in movies:
    print(f"Fetching release date for: {movie}")
    release_date = get_release_date(movie)
    movie_release_dates.append({'Title': movie, 'Release Date': release_date})

# Create a DataFrame to organize the data
df = pd.DataFrame(movie_release_dates)

# Save the data to an Excel file
output_file = 'movie_release_dates3.xlsx'
df.to_excel(output_file, index=False)

print(f"Release dates extracted and saved to '{output_file}'")

# %%
import requests
import pandas as pd

# Your OMDb API key
API_KEY = '6f4c1d44'

# List of movie titles
movies = [
"Conclave", "Your Monster", "Don't Move", "Magpie", "La cocina", 
    "Darla in Space", "All You Need Is Blood", "1 Million Followers", 
    "Hangdog", "Let's Start a Cult", "Amityville: Where the Echo Lives", 
    "Time Cut", "Here", "Juror #2", "Blitz", "A Real Pain", "Absolution", 
    "The Gutter", "The Graduates", "The Eye of the Salamander", 
    "Lost on a Mountain in Maine", "Meet Me Next Christmas", 
    "A Sudden Case of Christmas", "Heretic", "The Best Christmas Pageant Ever", 
    "The Piano Lesson", "Elevation", "Christmas Eve in Miller's Point", 
    "Bird", "Love Bomb", "It's Coming", "Hot Frosty", "Red One", "Daruma", 
    "Breakup Season", "Swap", "The Merry Gentlemen", "Wicked", "Gladiator II", 
    "Spellbound", "Armor", "Out of My Mind", "Bonhoeffer", "The Fix", 
    "Dear Santa", "Watchmen Chapter II", "Hemet, or the Landlady Don't Drink Tea", 
    "A Great Divide", "Moana 2", "Maria", "Our Little Secret", "Sweethearts", 
    "Nutcrackers", "Y2K", "Nightbitch", "The Six Triple Eight", "The Order", 
    "Werewolves", "The Return", "Oh, Canada", "Mary", "Jenni", 
    "Kraven the Hunter", "The Lord of the Rings: The War of the Rohirrim", 
    "Carry-On", "Dirty Angels", "Filthy Animals", "The Activated Man", 
    "The Little Mermaid", "Glue Trap", "Mufasa: The Lion King", 
    "Sonic the Hedgehog 3", "Homestead", "Nosferatu", "A Complete Unknown", 
    "The Fire Inside", "Babygirl", "Los Frikis", "Bloody Axe Wound"
]

# Function to get the genre using OMDb API
def get_movie_genre(movie):
    url = f"http://www.omdbapi.com/?t={movie}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if data.get('Response') == 'True':
        return data.get('Genre')
    else:
        return None

# List to store movie names and their genres
movie_genres = []

# Loop through the movie list and get genres
for movie in movies:
    print(f"Fetching genre for: {movie}")
    genre = get_movie_genre(movie)
    movie_genres.append({'Title': movie, 'Genre': genre})

# Create a DataFrame to organize the data
df = pd.DataFrame(movie_genres)

# Save the data to an Excel file
output_file = 'movie_genres3.xlsx'
df.to_excel(output_file, index=False)

print(f"Genres extracted and saved to '{output_file}'")

# %%
import requests
import pandas as pd

# OMDb API Key
API_KEY = '6f4c1d44'

# List of movie titles
movies = [
    "Slingshot",
    "The Wasp",
    "Reagan",
    "First Shift",
    "You Gotta Believe",
    "City of Dreams",
    "Tokyo Cowboy",
    "Wolves Against the World",
    "Beetlejuice Beetlejuice",
    "The Front Room",
    "His Three Daughters",
    "Rebel Ridge",
    "Continue",
    "A New York Story",
    "The Thicket",
    "I'll Be Right There",
    "Speak No Evil",
    "The Killer's Game",
    "My Old Ass",
    "Uglies",
    "Winner",
    "Here After",
    "The 4:30 Movie",
    "Subservience",
    "Booger",
    "The Waterboyz",
    "Transformers One",
    "Wolfs",
    "Never Let Go",
    "The Substance",
    "A Different Man",
    "Bagman",
    "Omni Loop",
    "The Featherweight",
    "In the Summers",
    "Kill 'Em All 2",
    "Paradox Effect",
    "Killer Heat",
    "The Wild Robot",
    "Saturday Night",
    "Megalopolis",
    "Apartment 7A",
    "Rez Ball",
    "The Curse of the Necklace",
    "Azrael",
    "Amber Alert",
    "Abruptio",
    "She Taught Love",
    "Another Happy Day",
    "Crackcoon",
    "'Salem's Lot",
    "House of Spoils",
    "Hold Your Breath",
    "Joker: Folie à Deux",
    "White Bird",
    "It's What's Inside",
    "Monster Summer",
    "Things Will Be Different",
    "The Forest Hills",
    "The Problem with People",
    "Little Bites",
    "Hellboy: The Crooked Man",
    "Brothers",
    "Caddo Lake",
    "Terrifier 3",
    "Piece by Piece",
    "The Apprentice",
    "Lonely Planet",
    "The Silent Hour",
    "Bad Genius",
    "Seven Cemeteries",
    "The Man in the White Van",
    "9 Windows",
    "Smile 2",
    "Anora",
    "Goodrich",
    "Woman of the Hour",
    "The Line",
    "Exhibiting Forgiveness",
    "High Tide",
    "To Fall in Love",
    "Canary Black",
    "Venom: The Last Dance",
    "Conclave",
    "Your Monster",
    "Don't Move",
    "Magpie",
    "La cocina",
    "Darla in Space",
    "All You Need Is Blood",
    "1 Million Followers",
    "Hangdog",
    "Let's Start a Cult",
    "Amityville: Where the Echo Lives",
    "Time Cut",
    "Here",
    "Juror #2",
    "Blitz",
    "A Real Pain",
    "Absolution",
    "The Gutter",
    "The Graduates",
    "The Eye of the Salamander",
    "Lost on a Mountain in Maine",
    "Meet Me Next Christmas",
    "A Sudden Case of Christmas",
    "Heretic",
    "The Best Christmas Pageant Ever",
    "The Piano Lesson",
    "Elevation",
    "Christmas Eve in Miller's Point",
    "Bird",
    "Love Bomb",
    "It's Coming",
    "Hot Frosty",
    "Red One",
    "Daruma",
    "Breakup Season",
    "Swap",
    "The Merry Gentlemen",
    "Wicked",
    "Gladiator II",
    "Spellbound",
    "Armor",
    "Out of My Mind",
    "Bonhoeffer",
    "The Fix",
    "Dear Santa",
    "Watchmen Chapter II",
    "Hemet, or the Landlady Don't Drink Tea",
    "A Great Divide",
    "Moana 2",
    "Maria",
    "Our Little Secret",
    "Sweethearts",
    "Nutcrackers",
    "Y2K",
    "Nightbitch",
    "The Six Triple Eight",
    "The Order",
    "Werewolves",
    "The Return",
    "Oh, Canada",
    "Mary",
    "Jenni",
    "Kraven the Hunter",
    "The Lord of the Rings: The War of the Rohirrim",
    "Carry-On",
    "Dirty Angels",
    "Filthy Animals",
    "The Activated Man",
    "The Little Mermaid",
    "Glue Trap",
    "Mufasa: The Lion King",
    "Sonic the Hedgehog 3",
    "Homestead",
    "Nosferatu",
    "A Complete Unknown",
    "The Fire Inside",
    "Babygirl",
    "Los Frikis",
    "Bloody Axe Wound"
]



# Function to fetch runtime from OMDb API
def get_movie_runtime(movie):
    url = f"http://www.omdbapi.com/?t={movie}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    if data.get('Response') == 'True':
        return data.get('Runtime')
    else:
        return "Not Found"

# List to store the data
movie_data = []

# Loop through each movie to get runtime
for movie in movies:
    runtime = get_movie_runtime(movie)
    print(f"Fetched runtime for {movie}: {runtime}")
    movie_data.append({'Title': movie, 'Runtime': runtime})

# Save to a DataFrame and export to Excel
df = pd.DataFrame(movie_data)
df.to_excel('movie_runtimes3.xlsx', index=False)

print("Movie runtimes saved to 'movie_runtimes.xlsx'")
# Out:
# Fetched runtime for Slingshot: 108 min
# Fetched runtime for The Wasp: 96 min
# Fetched runtime for Reagan: 141 min
# Fetched runtime for First Shift: 89 min
# Fetched runtime for You Gotta Believe: 104 min
# Fetched runtime for City of Dreams: 31S min
# Fetched runtime for Tokyo Cowboy: 118 min
# Fetched runtime for Wolves Against the World: 88 min
# Fetched runtime for Beetlejuice Beetlejuice: 105 min
# Fetched runtime for The Front Room: 94 min
# Fetched runtime for His Three Daughters: 101 min
# Fetched runtime for Rebel Ridge: 131 min
# Fetched runtime for Continue: 115 min
# Fetched runtime for A New York Story: 96 min
# Fetched runtime for The Thicket: 108 min
# Fetched runtime for I'll Be Right There: 98 min
# Fetched runtime for Speak No Evil: 110 min
# Fetched runtime for The Killer's Game: 104 min
# Fetched runtime for My Old Ass: 89 min
# Fetched runtime for Uglies: 100 min
# Fetched runtime for Winner: 103 min
# Fetched runtime for Here After: 121 min
# ...

# %%
import requests
import csv

# List of movies
movie_list = [
    "The Mummy Murders", "Self Reliance", "DarkGame", "Night Swim", "He Went That Way",
    "The Painter", "The Bricklayer", "Some Other Woman", "Fugitive Dreams", "Husband for Sale",
    "The Beekeeper", "Mean Girls", "The Book of Clarence", "Lift", "Role Play", "The Night They Came Home",
    "Destroy All Neighbors", "Hellhound", "Wanted Man", "I.S.S.", "Sunrise", "Which Brings Me to You",
    "Cult Killer", "Founders Day", "Murder and Cocktails", "Beautiful Wedding", "Miller's Girl",
    "The Underdoggs", "Sometimes I Think About Dying", "American Star", "Cold Copy", "Junction",
    "Hundreds of Beavers", "There Is a Monster", "Argylle", "Orion and the Dark", "The Tiger's Apprentice",
    "Suncoast", "Scrambled", "Bosco", "Somewhere Quiet", "The Monk and the Gun", "A Nashville Wish",
    "Lisa Frankenstein", "Upgraded", "Air Force One Down", "Lola", "Marmalade", "ElemenTory", "Bob Marley: One Love",
    "Madame Web", "Players", "What About Love", "Adam the First", "Stranger in the Woods", "This Is Me... Now: A Love Story",
    "Land of Bad", "Bleeding Love", "Lights Out", "No Way Up", "Altered Reality", "Lovely, Dark, and Deep",
    "Drive-Away Dolls", "Ordinary Angels", "Mea Culpa", "Drugstore June", "Parallel", "Red Right Hand", "Blue Christmas",
    "The Neon Highway", "Dune: Part Two", "Spaceman", "Problemista", "Megamind vs. the Doom Syndicate", "Outlaw Posse",
    "Asleep in My Palm", "Ricky Stanicky", "The Thundermans Return", "Kung Fu Panda 4", "Imaginary", "Damsel",
    "Love Lies Bleeding", "Cabrini", "Accidental Texan", "American Dreamer", "Night Shift", "Glitter & Doom",
    "The Primevals", "Little Wing", "Arthur the King", "The American Society of Magical Negroes", "Shirley", "Irish Wish",
    "One Life", "Knox Goes Away", "Snack Shack", "Prey", "Bardejov", "Road House", "Earlybird", "Ghostbusters: Frozen Empire",
    "Immaculate", "Late Night with the Devil", "Sleeping Dogs", "The Casagrandes Movie", "Peter Five Eight", "Riddle of Fire",
    "Free Time", "Easter Bloody Easter", "Godzilla x Kong: The New Empire", "Asphalt City", "The Listener", "Lousy Carter"
]

# API URL and your API key
api_url = "http://www.omdbapi.com/"
api_key = "6f4c1d44"  # Replace with your actual API key

# Function to get movie details from OMDb API
def get_movie_details(movie):
    params = {
        't': movie,
        'apikey': api_key
    }
    
    response = requests.get(api_url, params=params)
    data = response.json()
    
    # Extract title, genre, and runtime
    if data['Response'] == 'True':
        title = data.get('Title', 'N/A')
        genre = data.get('Genre', 'N/A')
        runtime = data.get('Runtime', 'N/A')
        
        return title, genre, runtime
    else:
        return movie, 'N/A', 'N/A'

# Loop through each movie and get details
movie_details = []
for movie in movie_list:
    details = get_movie_details(movie)
    movie_details.append(details)

# Write movie details to CSV file
with open('movie_details_set1.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['Title', 'Genre', 'Runtime'])
    
    # Write movie details
    for details in movie_details:
        writer.writerow(details)

print("Movie details have been written to 'movie_details.csv'")
# Out:
# Movie details have been written to 'movie_details.csv'
